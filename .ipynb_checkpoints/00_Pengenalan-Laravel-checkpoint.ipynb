# %% [markdown]
# # Pengenalan Laravel

# %% [markdown]
# ## Apa Itu Laravel?

# %% [markdown]
# Beberapa point tentang Laravel:
# - PHP Framework yang dikembangkan oleh Taylor Otwell
# - Memiliki design (MVC) Model, View, Controller
# - Punya command line interface yang dikenal dengan Artisan. Yang membantu proses mempercepat proses pengembangan aplikasi.
# - Punya banyak komunitas di seluruh dunia

# %% [markdown]
# ## Popularitas di Indonesia

# %% [markdown]
# ![Screenshot%202022-08-09%20050129.png](attachment:Screenshot%202022-08-09%20050129.png)
#
# Di Indonesia Laravel masih mendukuduki peringat atas dalam pencarian, jika dibandingkan dengan Codeigniter, CakePHP, dan Symfony

# %% [markdown]
# ## Daftar Istilah

# %% [markdown]
# Beberapa istilah yang perlu dijelaskan secara singkat:
# - **Framework**:
